# %% [markdown]
# # 🎬 Chapter A10: Post-Processing Effects
#
# Raw 3D rendering looks "videogame-y".
# Post-processing makes it look **cinematic**.
#
# Effects like bloom, motion blur, and color grading transform good graphics into AAA visuals.

# %% [markdown]
# ## 1. Rendering to a Framebuffer

# %%
# Create offscreen render target
screen_texture = ctx.texture((800, 600), 3)
fbo = ctx.framebuffer(color_attachments=[screen_texture])

# Render scene to FBO
fbo.use()
# ... render scene ...

# Now apply post-processing to screen_texture

# %% [markdown]
# ## 🛠️ Challenge: Cinematic Pipeline
#
# Build a complete post-processing system:
#
# 1. Implement bloom (glowing lights)
# 2. Add HDR tone mapping
# 3. Implement color grading for mood
# 4. Add vignette effect
#
# If your game looks like a movie, you've achieved cinematic quality! 🎥
