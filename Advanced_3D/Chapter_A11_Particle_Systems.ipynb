# %% [markdown]
# # ✨ Chapter A11: Particle Systems (GPU Instancing)
#
# Explosions, fire, smoke, magic spells—all use **particle systems**.
#
# Rendering 10,000 particles individually = slow.
# **GPU instancing** = render 10,000 particles in one draw call.
#
# This is how AAA games render massive effects.

# %% [markdown]
# ## 1. Instanced Rendering

# %%
# Particle data (position, color, size)
particle_data = np.array([...], dtype='f4')
instance_vbo = ctx.buffer(particle_data.tobytes())

# Render all particles at once
vao.render(instances=10000)

# %% [markdown]
# ## 🛠️ Challenge: Explosion Effect
#
# Create a realistic explosion:
#
# 1. Spawn 5,000 particles
# 2. Use instanced rendering
# 3. Animate with physics (gravity, velocity)
# 4. Fade out over time
#
# If you can render realistic fire and smoke, you've mastered VFX! 🔥
